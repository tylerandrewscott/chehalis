# %% [markdown]
# # Textract EDS Adapter
#
# This notebook processes PDF documents using AWS Textract with a custom adapter. It:
# 1. Reads the zero-shot results CSV to identify documents with forms
# 2. Extracts the lowest page number from each document's form_pages
# 3. Sends individual pages to Textract using the custom adapter

# %%
import pandas as pd
import boto3
import os
from pathlib import Path
import json
from typing import List, Dict, Any
import PyPDF2
from io import BytesIO
import base64

# %% [markdown]
# ## Configuration

# %%
# Configuration
CLOBBER = False  # Set to True to overwrite existing results, False to skip already processed files

# File paths
CSV_PATH = "../../code/preprocessing/zero_shot_results_full_corpus.csv"
CONTRACTS_DIR = "../../data/raw/_contracts/"
OUTPUT_DIR = "../../data/intermediate_products/eds_forms_textract/"

# AWS Textract configuration
REGION_NAME = "us-east-1"  # Update with your region
CUSTOM_ADAPTER_ID = "4403a7771cbe"  # Update with your custom adapter ID
ADAPTER_VERSION = "2"  # Update with your adapter version

# Feature types - only QUERIES works with custom adapters
ADAPTER_FEATURE_TYPES = ['QUERIES']

# Queries for the EDS form extraction
DEFAULT_QUERIES = [
    "EDS Number",
    "Date Prepared",
    "Which response options in the \"3. CONTRACTS & LEASES\" box are checked?",
    #"Account Number",
    "Total amount this action:",
    "New contract total",
    #"Revenue generated this action:",
    #"Revenue generated total contract:",
    "From (month/day, year)",
    "To (month, day, year)",
    "Which option in the \"13. Method of source selection:\" box is selected?",
    "Name of agency:",
    #"Name listed for item \"17. Name\" under AGENCY CONTACT INFORMATION?",
    "Vendor ID #",
    "Vendor Name",
    #"Is \"Yes\" checked for 'Is the vendor registered with the Secretary of State'?",
    "Is \"Yes\" checked for Primary Vendor: Minority:'?",
    "Is \"Yes\" checked for Primary Vendor: Women:'?",
    #"Is \"Yes\" checked for Sub Vendor: Minority:'?",
    #"Is \"Yes\" checked for Sub Vendor: Women:'?",
    "Is \"Yes\" checked for 'Is there Renewal Language in the document'?",
    "Is \"Yes\" checked for 'Is there a Termination for Convenience\" clause in the document'?"
]

# Initialize AWS client
textract_client = boto3.client('textract', region_name=REGION_NAME)

# %% [markdown]
# ## Load and Filter Data

# %%
# Load the CSV file
df = pd.read_csv(CSV_PATH)
print(f"Total documents in CSV: {len(df)}")

# Filter for documents containing forms
forms_df = df[df['contains_form'] == True].copy()
print(f"Documents with forms: {len(forms_df)}")

# Display sample of filtered data
print("\nSample of documents with forms:")
print(forms_df[['filename', 'form_pages', 'num_form_pages']].head())
# Out:
# Total documents in CSV: 42490
# Documents with forms: 26109
#
# Sample of documents with forms:
#                                filename      form_pages  num_form_pages
# 804                           0-001.pdf  1,2,4,10,15,16               6
# 956   0000000000000000000021689-004.pdf               5               1
# 1660  0000000000000000000025661-003.pdf               5               1
# 2895  0000000000000000000029856-000.pdf               1               1
# 3996  0000000000000000000031808-000.pdf               1               1

# %% [markdown]
# ## Helper Functions

# %%
def get_lowest_page_number(form_pages_str: str) -> int:
    """
    Extract the lowest page number from the form_pages string.
    
    Args:
        form_pages_str: String containing page numbers (e.g., "1,2,4,10,15,16" or "5")
    
    Returns:
        int: The lowest page number
    """
    if pd.isna(form_pages_str) or form_pages_str == "":
        return None
    
    # Handle both single numbers and comma-separated lists
    if ',' in str(form_pages_str):
        page_numbers = [int(x.strip()) for x in str(form_pages_str).split(',')]
    else:
        page_numbers = [int(str(form_pages_str).strip())]
    
    return min(page_numbers)

def get_output_filename(filename: str, page_number: int) -> str:
    """
    Generate the output JSON filename for a given PDF and page number.
    
    Args:
        filename: Original PDF filename
        page_number: Page number
    
    Returns:
        str: Output JSON filename
    """
    filename_base = Path(filename).stem
    return f"{filename_base}_page_{page_number}_textract.json"

def file_already_processed(filename: str, page_number: int, output_dir: Path) -> bool:
    """
    Check if a file has already been processed.
    
    Args:
        filename: Original PDF filename
        page_number: Page number
        output_dir: Output directory path
    
    Returns:
        bool: True if file exists and has been processed
    """
    json_filename = get_output_filename(filename, page_number)
    json_path = output_dir / json_filename
    return json_path.exists() and json_path.stat().st_size > 0

def extract_single_page_pdf(pdf_path: str, page_number: int) -> bytes:
    """
    Extract a single page from a PDF file.
    
    Args:
        pdf_path: Path to the PDF file
        page_number: Page number to extract (1-indexed)
    
    Returns:
        bytes: PDF content of the single page
    """
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        pdf_writer = PyPDF2.PdfWriter()
        
        # PyPDF2 uses 0-based indexing, so subtract 1
        pdf_writer.add_page(pdf_reader.pages[page_number - 1])
        
        output_buffer = BytesIO()
        pdf_writer.write(output_buffer)
        return output_buffer.getvalue()

def process_with_textract(pdf_bytes: bytes, adapter_id: str, queries: List[str] = None) -> Dict[str, Any]:
    """
    Process a PDF page with Textract using a custom adapter.
    
    Args:
        pdf_bytes: PDF content as bytes
        adapter_id: Custom adapter ID
        queries: List of queries for the adapter (uses DEFAULT_QUERIES if not provided)
    
    Returns:
        dict: Textract response
    """
    try:
        # Use provided queries or default queries
        if queries is None:
            queries = DEFAULT_QUERIES
        
        # Prepare the request parameters
        request_params = {
            'Document': {'Bytes': pdf_bytes},
            'FeatureTypes': ADAPTER_FEATURE_TYPES,
            'QueriesConfig': {
                'Queries': [{'Text': query} for query in queries]
            },
            'AdaptersConfig': {
                'Adapters': [
                    {
                        'AdapterId': adapter_id,
                        'Version': ADAPTER_VERSION
                    }
                ]
            }
        }
        
        response = textract_client.analyze_document(**request_params)
        return response
    except Exception as e:
        print(f"Error processing with Textract: {str(e)}")
        return None

# %% [markdown]
# ## Process Documents

# %%
# Add lowest page number to dataframe
forms_df['lowest_page'] = forms_df['form_pages'].apply(get_lowest_page_number)

# Remove rows where we couldn't determine the lowest page
forms_df = forms_df.dropna(subset=['lowest_page'])
forms_df['lowest_page'] = forms_df['lowest_page'].astype(int)

print(f"Documents with valid page numbers: {len(forms_df)}")
print("\nSample with lowest page numbers:")
print(forms_df[['filename', 'form_pages', 'lowest_page']].head(10))
# Out:
# Documents with valid page numbers: 26109
#
# Sample with lowest page numbers:
#                                filename      form_pages  lowest_page
# 804                           0-001.pdf  1,2,4,10,15,16            1
# 956   0000000000000000000021689-004.pdf               5            5
# 1660  0000000000000000000025661-003.pdf               5            5
# 2895  0000000000000000000029856-000.pdf               1            1
# 3996  0000000000000000000031808-000.pdf               1            1
# 4488  0000000000000000000034656-000.pdf               1            1
# 5734  0000000000000000000036599-001.pdf               4            4
# 5749  0000000000000000000036618-001.pdf               4            4
# 5841  0000000000000000000036347-001.pdf            3,10            3
# 7128  0000000000000000000038668-000.pdf              14           14

# %%
# Create output directory if it doesn't exist
output_dir = Path(OUTPUT_DIR)
output_dir.mkdir(parents=True, exist_ok=True)

# Check existing results if CLOBBER is False
if not CLOBBER:
    print("CLOBBER = False: Checking for existing results...")
    already_processed = []
    for idx, row in forms_df.iterrows():
        filename = row['filename']
        lowest_page = row['lowest_page']
        if file_already_processed(filename, lowest_page, output_dir):
            already_processed.append(filename)
    
    if already_processed:
        print(f"Found {len(already_processed)} already processed files. Skipping these.")
        # Filter out already processed files
        forms_df = forms_df[~forms_df['filename'].isin(already_processed)]
        print(f"Remaining files to process: {len(forms_df)}")
    else:
        print("No existing results found. Processing all files.")
else:
    print("CLOBBER = True: Processing all files (will overwrite existing results)")

# Process each document
results = []
errors = []
skipped = []

for idx, row in forms_df.iterrows():
    filename = row['filename']
    lowest_page = row['lowest_page']
    
    pdf_path = os.path.join(CONTRACTS_DIR, filename)
    
    # Check if file exists
    if not os.path.exists(pdf_path):
        error_msg = f"File not found: {filename}"
        print(error_msg)
        errors.append({'filename': filename, 'error': error_msg})
        continue
    
    # Double-check if file already processed (in case of race conditions)
    if not CLOBBER and file_already_processed(filename, lowest_page, output_dir):
        print(f"⏭ Skipping {filename} (already processed)")
        skipped.append({'filename': filename, 'page_number': lowest_page})
        continue
    
    try:
        print(f"Processing {filename}, page {lowest_page}...")
        
        # Extract the specific page
        page_pdf_bytes = extract_single_page_pdf(pdf_path, lowest_page)
        
        # Process with Textract
        textract_response = process_with_textract(page_pdf_bytes, CUSTOM_ADAPTER_ID)
        
        if textract_response:
            # Save result immediately to avoid losing work
            json_filename = get_output_filename(filename, lowest_page)
            json_path = output_dir / json_filename
            
            with open(json_path, 'w') as f:
                json.dump(textract_response, f, indent=2, default=str)
            
            result = {
                'filename': filename,
                'page_number': lowest_page,
                'json_file': json_filename,
                'status': 'success'
            }
            results.append(result)
            print(f"✓ Successfully processed {filename} → {json_filename}")
        else:
            error_msg = f"Textract processing failed for {filename}"
            print(f"✗ {error_msg}")
            errors.append({'filename': filename, 'error': error_msg})
            
    except Exception as e:
        error_msg = f"Error processing {filename}: {str(e)}"
        print(f"✗ {error_msg}")
        errors.append({'filename': filename, 'error': error_msg})

print(f"\nProcessing complete!")
print(f"Successfully processed: {len(results)} documents")
print(f"Skipped (already processed): {len(skipped)} documents")
print(f"Errors: {len(errors)} documents")
# Out:
# CLOBBER = False: Checking for existing results...
# No existing results found. Processing all files.
# Processing 0-001.pdf, page 1...
# ✓ Successfully processed 0-001.pdf → 0-001_page_1_textract.json
# Processing 0000000000000000000021689-004.pdf, page 5...
# ✓ Successfully processed 0000000000000000000021689-004.pdf → 0000000000000000000021689-004_page_5_textract.json
# Processing 0000000000000000000025661-003.pdf, page 5...
# ✓ Successfully processed 0000000000000000000025661-003.pdf → 0000000000000000000025661-003_page_5_textract.json
# Processing 0000000000000000000029856-000.pdf, page 1...
# ✓ Successfully processed 0000000000000000000029856-000.pdf → 0000000000000000000029856-000_page_1_textract.json
# Processing 0000000000000000000031808-000.pdf, page 1...
# ✓ Successfully processed 0000000000000000000031808-000.pdf → 0000000000000000000031808-000_page_1_textract.json
# Processing 0000000000000000000034656-000.pdf, page 1...
# ✓ Successfully processed 0000000000000000000034656-000.pdf → 0000000000000000000034656-000_page_1_textract.json
# Processing 0000000000000000000036599-001.pdf, page 4...
# ✓ Successfully processed 0000000000000000000036599-001.pdf → 0000000000000000000036599-001_page_4_textract.json
# Processing 0000000000000000000036618-001.pdf, page 4...
# ✓ Successfully processed 0000000000000000000036618-001.pdf → 0000000000000000000036618-001_page_4_textract.json
# Processing 0000000000000000000036347-001.pdf, page 3...
# ✓ Successfully processed 0000000000000000000036347-001.pdf → 0000000000000000000036347-001_page_3_textract.json
# Processing 0000000000000000000038668-000.pdf, page 14...
# ✓ Successfully processed 0000000000000000000038668-000.pdf → 0000000000000000000038668-000_page_14_textract.json
# Processing 0000000000000000000038918-001.pdf, page 15...
# ✓ Successfully processed 0000000000000000000038918-001.pdf → 0000000000000000000038918-001_page_15_textract.json
# Processing 0000000000000000000039452-001.pdf, page 3...
# ✓ Successfully processed 0000000000000000000039452-001.pdf → 0000000000000000000039452-001_page_3_textract.json
# Processing 0000000000000000000039417-002.pdf, page 3...
# ✓ Successfully processed 0000000000000000000039417-002.pdf → 0000000000000000000039417-002_page_3_textract.json
# Processing 0000000000000000000039579-001.pdf, page 3...
# ✓ Successfully processed 0000000000000000000039579-001.pdf → 0000000000000000000039579-001_page_3_textract.json
# Processing 0000000000000000000039806-000.pdf, page 11...
# ✓ Successfully processed 0000000000000000000039806-000.pdf → 0000000000000000000039806-000_page_11_textract.json
# Processing 0000000000000000000039845-001.pdf, page 3...
# ✓ Successfully processed 0000000000000000000039845-001.pdf → 0000000000000000000039845-001_page_3_textract.json
# Processing 0000000000000000000039849-001.pdf, page 3...
# ✓ Successfully processed 0000000000000000000039849-001.pdf → 0000000000000000000039849-001_page_3_textract.json
# Processing 0000000000000000000039847-001.pdf, page 3...
# ✓ Successfully processed 0000000000000000000039847-001.pdf → 0000000000000000000039847-001_page_3_textract.json
# Processing 0000000000000000000039850-001.pdf, page 3...
# ✓ Successfully processed 0000000000000000000039850-001.pdf → 0000000000000000000039850-001_page_3_textract.json
# Processing 0000000000000000000039846-001.pdf, page 3...
# ✓ Successfully processed 0000000000000000000039846-001.pdf → 0000000000000000000039846-001_page_3_textract.json
# Processing 0000000000000000000039846-002.pdf, page 3...
# ✓ Successfully processed 0000000000000000000039846-002.pdf → 0000000000000000000039846-002_page_3_textract.json
# Processing 0000000000000000000039976-001.pdf, page 6...
# ✓ Successfully processed 0000000000000000000039976-001.pdf → 0000000000000000000039976-001_page_6_textract.json
# Processing 0000000000000000000040217-001.pdf, page 3...
# ✓ Successfully processed 0000000000000000000040217-001.pdf → 0000000000000000000040217-001_page_3_textract.json
# Processing 0000000000000000000040451-000.pdf, page 16...
# ✓ Successfully processed 0000000000000000000040451-000.pdf → 0000000000000000000040451-000_page_16_textract.json
# Processing 0000000000000000000041271-001.pdf, page 17...
# ✓ Successfully processed 0000000000000000000041271-001.pdf → 0000000000000000000041271-001_page_17_textract.json
# Processing 0000000000000000000048512-002.pdf, page 1...
# ✓ Successfully processed 0000000000000000000048512-002.pdf → 0000000000000000000048512-002_page_1_textract.json
# Processing 0000000000000000000055177-000.pdf, page 16...
# ✓ Successfully processed 0000000000000000000055177-000.pdf → 0000000000000000000055177-000_page_16_textract.json
# Processing 0000000000000000000041742-000.pdf, page 156...
# ✓ Successfully processed 0000000000000000000041742-000.pdf → 0000000000000000000041742-000_page_156_textract.json
# Processing 0000000000000000000067712-000.pdf, page 16...
# ✓ Successfully processed 0000000000000000000067712-000.pdf → 0000000000000000000067712-000_page_16_textract.json
# Processing 0000000000000000000081653-000.pdf, page 16...
# ✓ Successfully processed 0000000000000000000081653-000.pdf → 0000000000000000000081653-000_page_16_textract.json
# Processing 0000000000000000000082482-000.pdf, page 16...
# ✓ Successfully processed 0000000000000000000082482-000.pdf → 0000000000000000000082482-000_page_16_textract.json
# Processing 0000000000000000000083053-000.pdf, page 21...
# ✓ Successfully processed 0000000000000000000083053-000.pdf → 0000000000000000000083053-000_page_21_textract.json
# Processing 0000000000000000000084914-000.pdf, page 20...
# ✓ Successfully processed 0000000000000000000084914-000.pdf → 0000000000000000000084914-000_page_20_textract.json
# Processing 0000000000000000000084655-000.pdf, page 45...
# ✓ Successfully processed 0000000000000000000084655-000.pdf → 0000000000000000000084655-000_page_45_textract.json
# Processing 0070420201-001.pdf, page 1...
# ✓ Successfully processed 0070420201-001.pdf → 0070420201-001_page_1_textract.json
# Processing 10006-000.pdf, page 1...
# ✓ Successfully processed 10006-000.pdf → 10006-000_page_1_textract.json
# Processing 10011-000.pdf, page 1...
# ✓ Successfully processed 10011-000.pdf → 10011-000_page_1_textract.json
# Processing 10013-000.pdf, page 1...
# ✓ Successfully processed 10013-000.pdf → 10013-000_page_1_textract.json
# Processing 100013-001.pdf, page 1...
# ✓ Successfully processed 100013-001.pdf → 100013-001_page_1_textract.json
# Processing 10027-000.pdf, page 1...
# ✓ Successfully processed 10027-000.pdf → 10027-000_page_1_textract.json
# Processing 10034-000.pdf, page 1...
# ✓ Successfully processed 10034-000.pdf → 10034-000_page_1_textract.json
# Processing 10039-000.pdf, page 1...
# ✓ Successfully processed 10039-000.pdf → 10039-000_page_1_textract.json
# Processing 10044-000.pdf, page 1...
# ✓ Successfully processed 10044-000.pdf → 10044-000_page_1_textract.json
# Processing 10042-000.pdf, page 1...
# ✓ Successfully processed 10042-000.pdf → 10042-000_page_1_textract.json
# Processing 10045-000.pdf, page 1...
# ✓ Successfully processed 10045-000.pdf → 10045-000_page_1_textract.json
# Processing 10052-000.pdf, page 1...
# ✓ Successfully processed 10052-000.pdf → 10052-000_page_1_textract.json
# Processing 100045-001.pdf, page 1...
# ✓ Successfully processed 100045-001.pdf → 100045-001_page_1_textract.json
# Processing 100140-001.pdf, page 1...
# ✓ Successfully processed 100140-001.pdf → 100140-001_page_1_textract.json
# Processing 100590-001.pdf, page 1...
# ✓ Successfully processed 100590-001.pdf → 100590-001_page_1_textract.json
# Processing 100455-001.pdf, page 1...
# ✓ Successfully processed 100455-001.pdf → 100455-001_page_1_textract.json
# Processing 10052-001.pdf, page 1...
# ✓ Successfully processed 10052-001.pdf → 10052-001_page_1_textract.json
# Processing 10062-001.pdf, page 1...
# ✓ Successfully processed 10062-001.pdf → 10062-001_page_1_textract.json
# Processing 100145-000.pdf, page 1...
# ✓ Successfully processed 100145-000.pdf → 100145-000_page_1_textract.json
# Processing 10065-001.pdf, page 1...
# ✓ Successfully processed 10065-001.pdf → 10065-001_page_1_textract.json
# Processing 10001-000.pdf, page 1...
# ✓ Successfully processed 10001-000.pdf → 10001-000_page_1_textract.json
# Processing 10070-003.pdf, page 1...
# ✓ Successfully processed 10070-003.pdf → 10070-003_page_1_textract.json
# Processing 0000000000000000000093233-000.pdf, page 23...
# ✓ Successfully processed 0000000000000000000093233-000.pdf → 0000000000000000000093233-000_page_23_textract.json
# Processing 100280-000.pdf, page 1...
# ✓ Successfully processed 100280-000.pdf → 100280-000_page_1_textract.json
# Processing 100590-000.pdf, page 1...
# ✓ Successfully processed 100590-000.pdf → 100590-000_page_1_textract.json
# Processing 10072-000.pdf, page 1...
# ✓ Successfully processed 10072-000.pdf → 10072-000_page_1_textract.json
# Processing 100015-000.pdf, page 1...
# ✓ Successfully processed 100015-000.pdf → 100015-000_page_1_textract.json
# Processing 100016-000.pdf, page 1...
# ✓ Successfully processed 100016-000.pdf → 100016-000_page_1_textract.json
# Processing 100026-000.pdf, page 1...
# ✓ Successfully processed 100026-000.pdf → 100026-000_page_1_textract.json
# Processing 100013-000.pdf, page 1...
# ✓ Successfully processed 100013-000.pdf → 100013-000_page_1_textract.json
# Processing 100093-000.pdf, page 1...
# ✓ Successfully processed 100093-000.pdf → 100093-000_page_1_textract.json
# Processing 10081-001.pdf, page 1...
# ✓ Successfully processed 10081-001.pdf → 10081-001_page_1_textract.json
# Processing 100616-000.pdf, page 1...
# ✓ Successfully processed 100616-000.pdf → 100616-000_page_1_textract.json
# Processing 10072-003.pdf, page 1...
# ✓ Successfully processed 10072-003.pdf → 10072-003_page_1_textract.json
# Processing 10070-005.pdf, page 1...
# ✓ Successfully processed 10070-005.pdf → 10070-005_page_1_textract.json
# Processing 10073-001.pdf, page 1...
# ✓ Successfully processed 10073-001.pdf → 10073-001_page_1_textract.json
# Processing 10075-001.pdf, page 1...
# ✓ Successfully processed 10075-001.pdf → 10075-001_page_1_textract.json
# Processing 100255-000.pdf, page 1...
# ✓ Successfully processed 100255-000.pdf → 100255-000_page_1_textract.json
# Processing 100271-000.pdf, page 1...
# ✓ Successfully processed 100271-000.pdf → 100271-000_page_1_textract.json
# Processing 100718-000.pdf, page 1...
# ✓ Successfully processed 100718-000.pdf → 100718-000_page_1_textract.json
# Processing 100256-000.pdf, page 1...
# ✓ Successfully processed 100256-000.pdf → 100256-000_page_1_textract.json
# Processing 100715-000.pdf, page 1...
# ✓ Successfully processed 100715-000.pdf → 100715-000_page_1_textract.json
# Processing 100253-000.pdf, page 1...
# ✓ Successfully processed 100253-000.pdf → 100253-000_page_1_textract.json
# Processing 100276-000.pdf, page 1...
# ✓ Successfully processed 100276-000.pdf → 100276-000_page_1_textract.json
# Processing 100274-000.pdf, page 1...
# ✓ Successfully processed 100274-000.pdf → 100274-000_page_1_textract.json
# Processing 100761-000.pdf, page 1...
# ✓ Successfully processed 100761-000.pdf → 100761-000_page_1_textract.json
# Processing 100762-000.pdf, page 1...
# ✓ Successfully processed 100762-000.pdf → 100762-000_page_1_textract.json
# Processing 10072-002.pdf, page 1...
# ✓ Successfully processed 10072-002.pdf → 10072-002_page_1_textract.json
# Processing 10114-000.pdf, page 1...
# ✓ Successfully processed 10114-000.pdf → 10114-000_page_1_textract.json
# Processing 10050-000.pdf, page 1...
# ✓ Successfully processed 10050-000.pdf → 10050-000_page_1_textract.json
# Processing 100957-001.pdf, page 1...
# ✓ Successfully processed 100957-001.pdf → 100957-001_page_1_textract.json
# Processing 10072-001.pdf, page 1...
# ✓ Successfully processed 10072-001.pdf → 10072-001_page_1_textract.json
# Processing 100390-000.pdf, page 1...
# ✓ Successfully processed 100390-000.pdf → 100390-000_page_1_textract.json
# Processing 100259-000.pdf, page 1...
# ✓ Successfully processed 100259-000.pdf → 100259-000_page_1_textract.json
# Processing 100028-000.pdf, page 1...
# ✓ Successfully processed 100028-000.pdf → 100028-000_page_1_textract.json
# Processing 101116-001.pdf, page 1...
# ✓ Successfully processed 101116-001.pdf → 101116-001_page_1_textract.json
# Processing 100825-000.pdf, page 1...
# ✓ Successfully processed 100825-000.pdf → 100825-000_page_1_textract.json
# Processing 100833-000.pdf, page 1...
# ✓ Successfully processed 100833-000.pdf → 100833-000_page_1_textract.json
# Processing 10133-000.pdf, page 1...
# ✓ Successfully processed 10133-000.pdf → 10133-000_page_1_textract.json
# Processing 10072-005.pdf, page 1...
# ✓ Successfully processed 10072-005.pdf → 10072-005_page_1_textract.json
# Processing 100835-000.pdf, page 1...
# ✓ Successfully processed 100835-000.pdf → 100835-000_page_1_textract.json
# Processing 101038-000.pdf, page 1...
# ✓ Successfully processed 101038-000.pdf → 101038-000_page_1_textract.json
# Processing 10054-002.pdf, page 1...
# ✓ Successfully processed 10054-002.pdf → 10054-002_page_1_textract.json
# Processing 10005-001.pdf, page 1...
# ✓ Successfully processed 10005-001.pdf → 10005-001_page_1_textract.json
# Processing 10142-000.pdf, page 1...
# ✓ Successfully processed 10142-000.pdf → 10142-000_page_1_textract.json
# Processing 10065-000.pdf, page 1...
# ✓ Successfully processed 10065-000.pdf → 10065-000_page_1_textract.json
# Processing 100349-000.pdf, page 1...
# ✓ Successfully processed 100349-000.pdf → 100349-000_page_1_textract.json
# Processing 10133-003.pdf, page 1...
# ✓ Successfully processed 10133-003.pdf → 10133-003_page_1_textract.json
# Processing 10145-000.pdf, page 1...
# ✓ Successfully processed 10145-000.pdf → 10145-000_page_1_textract.json
# Processing 10062-000.pdf, page 1...
# ✓ Successfully processed 10062-000.pdf → 10062-000_page_1_textract.json
# Processing 10148-000.pdf, page 1...
# ✓ Successfully processed 10148-000.pdf → 10148-000_page_1_textract.json
# Processing 10029-000.pdf, page 1...
# ✓ Successfully processed 10029-000.pdf → 10029-000_page_1_textract.json
# Processing 10151-000.pdf, page 1...
# ✓ Successfully processed 10151-000.pdf → 10151-000_page_1_textract.json
# Processing 10152-000.pdf, page 1...
# ✓ Successfully processed 10152-000.pdf → 10152-000_page_1_textract.json
# Processing 10154-000.pdf, page 1...
# ✓ Successfully processed 10154-000.pdf → 10154-000_page_1_textract.json
# Processing 100444-000.pdf, page 1...
# ✓ Successfully processed 100444-000.pdf → 100444-000_page_1_textract.json
# Processing 101093-001.pdf, page 1...
# ✓ Successfully processed 101093-001.pdf → 101093-001_page_1_textract.json
# Processing 10133-002.pdf, page 1...
# ✓ Successfully processed 10133-002.pdf → 10133-002_page_1_textract.json
# Processing 10158-000.pdf, page 1...
# ✓ Successfully processed 10158-000.pdf → 10158-000_page_1_textract.json
# Processing 100127-000.pdf, page 1...
# ✓ Successfully processed 100127-000.pdf → 100127-000_page_1_textract.json
# Processing 101083-001.pdf, page 1...
# ✓ Successfully processed 101083-001.pdf → 101083-001_page_1_textract.json
# Processing 10160-000.pdf, page 1...
# ✓ Successfully processed 10160-000.pdf → 10160-000_page_1_textract.json
# Processing 101497-001.pdf, page 1...
# ✓ Successfully processed 101497-001.pdf → 101497-001_page_1_textract.json
# Processing 100766-000.pdf, page 1...
# ✓ Successfully processed 100766-000.pdf → 100766-000_page_1_textract.json
# Processing 10162-000.pdf, page 1...
# ✓ Successfully processed 10162-000.pdf → 10162-000_page_1_textract.json
# Processing 100244-000.pdf, page 1...
# ✓ Successfully processed 100244-000.pdf → 100244-000_page_1_textract.json
# Processing 100819-000.pdf, page 1...
# ✓ Successfully processed 100819-000.pdf → 100819-000_page_1_textract.json
# Processing 100922-000.pdf, page 1...
# ✓ Successfully processed 100922-000.pdf → 100922-000_page_1_textract.json
# Processing 10164-000.pdf, page 1...
# ✓ Successfully processed 10164-000.pdf → 10164-000_page_1_textract.json
# Processing 100990-000.pdf, page 1...
# ✓ Successfully processed 100990-000.pdf → 100990-000_page_1_textract.json
# Processing 10166-000.pdf, page 1...
# ✓ Successfully processed 10166-000.pdf → 10166-000_page_1_textract.json
# Processing 100037-000.pdf, page 1...
# ✓ Successfully processed 100037-000.pdf → 100037-000_page_1_textract.json
# Processing 10093-000.pdf, page 1...
# ✓ Successfully processed 10093-000.pdf → 10093-000_page_1_textract.json
# Processing 100442-000.pdf, page 1...
# ✓ Successfully processed 100442-000.pdf → 100442-000_page_1_textract.json
# Processing 10073-000.pdf, page 1...
# ✓ Successfully processed 10073-000.pdf → 10073-000_page_1_textract.json
# Processing 10170-000.pdf, page 1...
# ✓ Successfully processed 10170-000.pdf → 10170-000_page_1_textract.json
# Processing 10075-000.pdf, page 1...
# ✓ Successfully processed 10075-000.pdf → 10075-000_page_1_textract.json
# Processing 100698-000.pdf, page 1...
# ✓ Successfully processed 100698-000.pdf → 100698-000_page_1_textract.json
# Processing 101044-000.pdf, page 1...
# ✓ Successfully processed 101044-000.pdf → 101044-000_page_1_textract.json
# Processing 100048-000.pdf, page 1...
# ✓ Successfully processed 100048-000.pdf → 100048-000_page_1_textract.json
# Processing 100046-000.pdf, page 1...
# ✓ Successfully processed 100046-000.pdf → 100046-000_page_1_textract.json
# Processing 100050-000.pdf, page 1...
# ✓ Successfully processed 100050-000.pdf → 100050-000_page_1_textract.json
# Processing 100888-000.pdf, page 1...
# ✓ Successfully processed 100888-000.pdf → 100888-000_page_1_textract.json
# Processing 100039-000.pdf, page 1...
# ✓ Successfully processed 100039-000.pdf → 100039-000_page_1_textract.json
# Processing 101053-000.pdf, page 1...
# ✓ Successfully processed 101053-000.pdf → 101053-000_page_1_textract.json
# Processing 101049-000.pdf, page 1...
# ✓ Successfully processed 101049-000.pdf → 101049-000_page_1_textract.json
# Processing 101079-000.pdf, page 1...
# ✓ Successfully processed 101079-000.pdf → 101079-000_page_1_textract.json
# Processing 10171-000.pdf, page 1...
# ✓ Successfully processed 10171-000.pdf → 10171-000_page_1_textract.json
# Processing 100082-000.pdf, page 1...
# ✓ Successfully processed 100082-000.pdf → 100082-000_page_1_textract.json
# Processing 100084-000.pdf, page 1...
# ✓ Successfully processed 100084-000.pdf → 100084-000_page_1_textract.json
# Processing 10177-000.pdf, page 1...
# ✓ Successfully processed 10177-000.pdf → 10177-000_page_1_textract.json
# Processing 100051-000.pdf, page 1...
# ✓ Successfully processed 100051-000.pdf → 100051-000_page_1_textract.json
# Processing 101034-000.pdf, page 1...
# ✓ Successfully processed 101034-000.pdf → 101034-000_page_1_textract.json
# Processing 100036-000.pdf, page 1...
# ✓ Successfully processed 100036-000.pdf → 100036-000_page_1_textract.json
# Processing 101210-000.pdf, page 1...
# ✓ Successfully processed 101210-000.pdf → 101210-000_page_1_textract.json
# Processing 100531-000.pdf, page 1...
# ✓ Successfully processed 100531-000.pdf → 100531-000_page_1_textract.json
# Processing 101116-000.pdf, page 1...
# ✓ Successfully processed 101116-000.pdf → 101116-000_page_1_textract.json
# Processing 101597-001.pdf, page 1...
# ✓ Successfully processed 101597-001.pdf → 101597-001_page_1_textract.json
# Processing 101093-000.pdf, page 1...
# ✓ Successfully processed 101093-000.pdf → 101093-000_page_1_textract.json
# Processing 100068-000.pdf, page 1...
# ✓ Successfully processed 100068-000.pdf → 100068-000_page_1_textract.json
# Processing 100061-000.pdf, page 1...
# ✓ Successfully processed 100061-000.pdf → 100061-000_page_1_textract.json
# Processing 10202-003.pdf, page 1...
# ✓ Successfully processed 10202-003.pdf → 10202-003_page_1_textract.json
# Processing 100085-000.pdf, page 1...
# ✓ Successfully processed 100085-000.pdf → 100085-000_page_1_textract.json
# Processing 101437-000.pdf, page 1...
# ✓ Successfully processed 101437-000.pdf → 101437-000_page_1_textract.json
# Processing 101219-000.pdf, page 1...
# ✓ Successfully processed 101219-000.pdf → 101219-000_page_1_textract.json
# Processing 100067-000.pdf, page 1...
# ✓ Successfully processed 100067-000.pdf → 100067-000_page_1_textract.json
# Processing 101477-000.pdf, page 1...
# ✓ Successfully processed 101477-000.pdf → 101477-000_page_1_textract.json
# Processing 101606-001.pdf, page 1...
# ✓ Successfully processed 101606-001.pdf → 101606-001_page_1_textract.json
# Processing 100053-000.pdf, page 1...
# ✓ Successfully processed 100053-000.pdf → 100053-000_page_1_textract.json
# Processing 100530-000.pdf, page 1...
# ✓ Successfully processed 100530-000.pdf → 100530-000_page_1_textract.json
# Processing 10202-005.pdf, page 1...
# ✓ Successfully processed 10202-005.pdf → 10202-005_page_1_textract.json
# Processing 101672-001.pdf, page 1...
# ✓ Successfully processed 101672-001.pdf → 101672-001_page_1_textract.json
# Processing 100047-000.pdf, page 1...
# ✓ Successfully processed 100047-000.pdf → 100047-000_page_1_textract.json
# Processing 102056-001.pdf, page 1...
# ✓ Successfully processed 102056-001.pdf → 102056-001_page_1_textract.json
# Processing 10222-001.pdf, page 1...
# ✓ Successfully processed 10222-001.pdf → 10222-001_page_1_textract.json
# Processing 101559-000.pdf, page 1...
# ✓ Successfully processed 101559-000.pdf → 101559-000_page_1_textract.json
# Processing 101657-001.pdf, page 1...
# ✓ Successfully processed 101657-001.pdf → 101657-001_page_1_textract.json
# Processing 101756-001.pdf, page 1...
# ✓ Successfully processed 101756-001.pdf → 101756-001_page_1_textract.json
# Processing 101092-000.pdf, page 1...
# ✓ Successfully processed 101092-000.pdf → 101092-000_page_1_textract.json
# Processing 101497-000.pdf, page 1...
# ✓ Successfully processed 101497-000.pdf → 101497-000_page_1_textract.json
# Processing 10231-003.pdf, page 1...
# ✓ Successfully processed 10231-003.pdf → 10231-003_page_1_textract.json
# Processing 100045-000.pdf, page 1...
# ✓ Successfully processed 100045-000.pdf → 100045-000_page_1_textract.json
# Processing 101702-001.pdf, page 1...
# ✓ Successfully processed 101702-001.pdf → 101702-001_page_1_textract.json
# Processing 101657-002.pdf, page 1...
# ✓ Successfully processed 101657-002.pdf → 101657-002_page_1_textract.json
# Processing 101083-000.pdf, page 1...
# ✓ Successfully processed 101083-000.pdf → 101083-000_page_1_textract.json
# Processing 10133-001.pdf, page 1...
# ✓ Successfully processed 10133-001.pdf → 10133-001_page_1_textract.json
# Processing 100579-000.pdf, page 1...
# ✓ Successfully processed 100579-000.pdf → 100579-000_page_1_textract.json
# Processing 100581-000.pdf, page 1...
# ✓ Successfully processed 100581-000.pdf → 100581-000_page_1_textract.json
# Processing 100586-000.pdf, page 1...
# ✓ Successfully processed 100586-000.pdf → 100586-000_page_1_textract.json
# Processing 100583-000.pdf, page 1...
# ✓ Successfully processed 100583-000.pdf → 100583-000_page_1_textract.json
# Processing 100584-000.pdf, page 1...
# ✓ Successfully processed 100584-000.pdf → 100584-000_page_1_textract.json
# Processing 100582-000.pdf, page 1...
# ✓ Successfully processed 100582-000.pdf → 100582-000_page_1_textract.json
# Processing 0000000000000000000093560-000.pdf, page 52...
# ✓ Successfully processed 0000000000000000000093560-000.pdf → 0000000000000000000093560-000_page_52_textract.json
# Processing 10259-002.pdf, page 1...
# ✓ Successfully processed 10259-002.pdf → 10259-002_page_1_textract.json
# Processing 10230-001.pdf, page 1...
# ✓ Successfully processed 10230-001.pdf → 10230-001_page_1_textract.json
# Processing 10105-001.pdf, page 1...
# ✓ Successfully processed 10105-001.pdf → 10105-001_page_1_textract.json
# Processing 10230-000.pdf, page 1...
# ✓ Successfully processed 10230-000.pdf → 10230-000_page_1_textract.json
# Processing 100140-000.pdf, page 1...
# ✓ Successfully processed 100140-000.pdf → 100140-000_page_1_textract.json
# Processing 100580-000.pdf, page 1...
# ✓ Successfully processed 100580-000.pdf → 100580-000_page_1_textract.json
# Processing 10230-002.pdf, page 1...
# ✓ Successfully processed 10230-002.pdf → 10230-002_page_1_textract.json
# Processing 100603-000.pdf, page 1...
# ✓ Successfully processed 100603-000.pdf → 100603-000_page_1_textract.json
# Processing 101708-000.pdf, page 1...
# ✓ Successfully processed 101708-000.pdf → 101708-000_page_1_textract.json
# Processing 10202-004.pdf, page 1...
# ✓ Successfully processed 10202-004.pdf → 10202-004_page_1_textract.json
# Processing 102502-001.pdf, page 1...
# ✓ Successfully processed 102502-001.pdf → 102502-001_page_1_textract.json
# Processing 101700-000.pdf, page 1...
# ✓ Successfully processed 101700-000.pdf → 101700-000_page_1_textract.json
# Processing 10251-005.pdf, page 1...
# ✓ Successfully processed 10251-005.pdf → 10251-005_page_1_textract.json
# Processing 100455-000.pdf, page 1...
# ✓ Successfully processed 100455-000.pdf → 100455-000_page_1_textract.json
# Processing 10280-001.pdf, page 1...
# ✓ Successfully processed 10280-001.pdf → 10280-001_page_1_textract.json
# Processing 10119-000.pdf, page 1...
# ✓ Successfully processed 10119-000.pdf → 10119-000_page_1_textract.json
# Processing 101818-000.pdf, page 1...
# ✓ Successfully processed 101818-000.pdf → 101818-000_page_1_textract.json
# Processing 10251-006.pdf, page 1...
# ✓ Successfully processed 10251-006.pdf → 10251-006_page_1_textract.json
# Processing 10070-004.pdf, page 1...
# ✓ Successfully processed 10070-004.pdf → 10070-004_page_1_textract.json
# Processing 10307-001.pdf, page 1...
# ✓ Successfully processed 10307-001.pdf → 10307-001_page_1_textract.json
# Processing 102738-001.pdf, page 1...
# ✓ Successfully processed 102738-001.pdf → 102738-001_page_1_textract.json
# Processing 102738-002.pdf, page 1...
# ✓ Successfully processed 102738-002.pdf → 102738-002_page_1_textract.json
# Processing 101809-000.pdf, page 1...
# ✓ Successfully processed 101809-000.pdf → 101809-000_page_1_textract.json
# Processing 10321-000.pdf, page 1...
# ✓ Successfully processed 10321-000.pdf → 10321-000_page_1_textract.json
# Processing 100648-000.pdf, page 1...
# ✓ Successfully processed 100648-000.pdf → 100648-000_page_1_textract.json
# Processing 100640-000.pdf, page 1...
# ✓ Successfully processed 100640-000.pdf → 100640-000_page_1_textract.json
# Processing 101118-000.pdf, page 1...
# ✓ Successfully processed 101118-000.pdf → 101118-000_page_1_textract.json
# Processing 100642-000.pdf, page 1...
# ✓ Successfully processed 100642-000.pdf → 100642-000_page_1_textract.json
# Processing 101597-000.pdf, page 1...
# ✓ Successfully processed 101597-000.pdf → 101597-000_page_1_textract.json
# Processing 101699-000.pdf, page 1...
# ✓ Successfully processed 101699-000.pdf → 101699-000_page_1_textract.json
# Processing 101832-000.pdf, page 1...
# ✓ Successfully processed 101832-000.pdf → 101832-000_page_1_textract.json
# Processing 100655-000.pdf, page 1...
# ✓ Successfully processed 100655-000.pdf → 100655-000_page_1_textract.json
# Processing 101834-000.pdf, page 1...
# ✓ Successfully processed 101834-000.pdf → 101834-000_page_1_textract.json
# Processing 101833-000.pdf, page 1...
# ✓ Successfully processed 101833-000.pdf → 101833-000_page_1_textract.json
# Processing 10230-003.pdf, page 1...
# ✓ Successfully processed 10230-003.pdf → 10230-003_page_1_textract.json
# Processing 101453-000.pdf, page 1...
# ✓ Successfully processed 101453-000.pdf → 101453-000_page_1_textract.json
# Processing 100653-000.pdf, page 1...
# ✓ Successfully processed 100653-000.pdf → 100653-000_page_1_textract.json
# Processing 100654-000.pdf, page 1...
# ✓ Successfully processed 100654-000.pdf → 100654-000_page_1_textract.json
# Processing 10072-004.pdf, page 1...
# ✓ Successfully processed 10072-004.pdf → 10072-004_page_1_textract.json
# Processing 100657-000.pdf, page 1...
# ✓ Successfully processed 100657-000.pdf → 100657-000_page_1_textract.json
# Processing 102513-000.pdf, page 1...
# ✓ Successfully processed 102513-000.pdf → 102513-000_page_1_textract.json
# Processing 10307-003.pdf, page 1...
# ✓ Successfully processed 10307-003.pdf → 10307-003_page_1_textract.json
# Processing 101701-000.pdf, page 1...
# ✓ Successfully processed 101701-000.pdf → 101701-000_page_1_textract.json
# Processing 100658-000.pdf, page 1...
# ✓ Successfully processed 100658-000.pdf → 100658-000_page_1_textract.json
# Processing 100645-000.pdf, page 1...
# ✓ Successfully processed 100645-000.pdf → 100645-000_page_1_textract.json
# Processing 10355-000.pdf, page 1...
# ✓ Successfully processed 10355-000.pdf → 10355-000_page_1_textract.json
# Processing 10359-000.pdf, page 1...
# ✓ Successfully processed 10359-000.pdf → 10359-000_page_1_textract.json
# Processing 100656-000.pdf, page 1...
# ✓ Successfully processed 100656-000.pdf → 100656-000_page_1_textract.json
# Processing 10364-000.pdf, page 1...
# ✓ Successfully processed 10364-000.pdf → 10364-000_page_1_textract.json
# Processing 10196-000.pdf, page 1...
# ✓ Successfully processed 10196-000.pdf → 10196-000_page_1_textract.json
# Processing 101772-000.pdf, page 1...
# ✓ Successfully processed 101772-000.pdf → 101772-000_page_1_textract.json
# Processing 10366-000.pdf, page 1...
# ✓ Successfully processed 10366-000.pdf → 10366-000_page_1_textract.json
# Processing 10367-000.pdf, page 1...
# ✓ Successfully processed 10367-000.pdf → 10367-000_page_1_textract.json
# Processing 100661-000.pdf, page 1...
# ✓ Successfully processed 100661-000.pdf → 100661-000_page_1_textract.json
# Processing 100660-000.pdf, page 1...
# ✓ Successfully processed 100660-000.pdf → 100660-000_page_1_textract.json
# Processing 101672-000.pdf, page 1...
# ✓ Successfully processed 101672-000.pdf → 101672-000_page_1_textract.json
# Processing 1017-000.pdf, page 1...
# ✓ Successfully processed 1017-000.pdf → 1017-000_page_1_textract.json
# Processing 10368-000.pdf, page 1...
# ✓ Successfully processed 10368-000.pdf → 10368-000_page_1_textract.json
# Processing 10372-000.pdf, page 1...
# ✓ Successfully processed 10372-000.pdf → 10372-000_page_1_textract.json
# Processing 100665-000.pdf, page 1...
# ✓ Successfully processed 100665-000.pdf → 100665-000_page_1_textract.json
# Processing 102086-000.pdf, page 1...
# ✓ Successfully processed 102086-000.pdf → 102086-000_page_1_textract.json
# Processing 100662-000.pdf, page 1...
# ✓ Successfully processed 100662-000.pdf → 100662-000_page_1_textract.json
# Processing 100666-000.pdf, page 1...
# ✓ Successfully processed 100666-000.pdf → 100666-000_page_1_textract.json
# Processing 10373-001.pdf, page 1...
# ✓ Successfully processed 10373-001.pdf → 10373-001_page_1_textract.json
# Processing 100659-000.pdf, page 1...
# ✓ Successfully processed 100659-000.pdf → 100659-000_page_1_textract.json
# Processing 100668-000.pdf, page 1...
# ✓ Successfully processed 100668-000.pdf → 100668-000_page_1_textract.json
# Processing 100663-000.pdf, page 1...
# ✓ Successfully processed 100663-000.pdf → 100663-000_page_1_textract.json
# Processing 100664-000.pdf, page 1...
# ✓ Successfully processed 100664-000.pdf → 100664-000_page_1_textract.json
# Processing 10321-002.pdf, page 1...
# ✓ Successfully processed 10321-002.pdf → 10321-002_page_1_textract.json
# Processing 10378-000.pdf, page 1...
# ✓ Successfully processed 10378-000.pdf → 10378-000_page_1_textract.json
# Processing 101054-000.pdf, page 1...
# ✓ Successfully processed 101054-000.pdf → 101054-000_page_1_textract.json
# Processing 10384-000.pdf, page 1...
# ✓ Successfully processed 10384-000.pdf → 10384-000_page_1_textract.json
# Processing 10120-000.pdf, page 1...
# ✓ Successfully processed 10120-000.pdf → 10120-000_page_1_textract.json
# Processing 100669-000.pdf, page 1...
# ✓ Successfully processed 100669-000.pdf → 100669-000_page_1_textract.json
# Processing 100508-000.pdf, page 1...
# ✓ Successfully processed 100508-000.pdf → 100508-000_page_1_textract.json
# Processing 101367-000.pdf, page 1...
# ✓ Successfully processed 101367-000.pdf → 101367-000_page_1_textract.json
# Processing 101606-000.pdf, page 1...
# ✓ Successfully processed 101606-000.pdf → 101606-000_page_1_textract.json
# Processing 100505-000.pdf, page 1...
# ✓ Successfully processed 100505-000.pdf → 100505-000_page_1_textract.json
# Processing 100529-000.pdf, page 1...
# ✓ Successfully processed 100529-000.pdf → 100529-000_page_1_textract.json
# Processing 100510-000.pdf, page 1...
# ✓ Successfully processed 100510-000.pdf → 100510-000_page_1_textract.json
# Processing 101363-000.pdf, page 1...
# ✓ Successfully processed 101363-000.pdf → 101363-000_page_1_textract.json
# Processing 100522-000.pdf, page 1...
# ✓ Successfully processed 100522-000.pdf → 100522-000_page_1_textract.json
# Processing 101702-000.pdf, page 1...
# ✓ Successfully processed 101702-000.pdf → 101702-000_page_1_textract.json
# Processing 10196-001.pdf, page 1...
# ✓ Successfully processed 10196-001.pdf → 10196-001_page_1_textract.json
# Processing 100504-000.pdf, page 1...
# ✓ Successfully processed 100504-000.pdf → 100504-000_page_1_textract.json
# Processing 100524-000.pdf, page 1...
# ✓ Successfully processed 100524-000.pdf → 100524-000_page_1_textract.json
# Processing 100507-000.pdf, page 1...
# ✓ Successfully processed 100507-000.pdf → 100507-000_page_1_textract.json
# Processing 100528-000.pdf, page 1...
# ✓ Successfully processed 100528-000.pdf → 100528-000_page_1_textract.json
# Processing 10359-001.pdf, page 1...
# ✓ Successfully processed 10359-001.pdf → 10359-001_page_1_textract.json
# Processing 1039-000.pdf, page 1...
# ✓ Successfully processed 1039-000.pdf → 1039-000_page_1_textract.json
# Processing 100512-000.pdf, page 1...
# ✓ Successfully processed 100512-000.pdf → 100512-000_page_1_textract.json
# Processing 10390-000.pdf, page 1...
# ✓ Successfully processed 10390-000.pdf → 10390-000_page_1_textract.json
# Processing 10393-000.pdf, page 1...
# ✓ Successfully processed 10393-000.pdf → 10393-000_page_1_textract.json
# Processing 10400-000.pdf, page 1...
# ✓ Successfully processed 10400-000.pdf → 10400-000_page_1_textract.json
# Processing 100667-000.pdf, page 1...
# ✓ Successfully processed 100667-000.pdf → 100667-000_page_1_textract.json
# Processing 10375-004.pdf, page 1...
# ✓ Successfully processed 10375-004.pdf → 10375-004_page_1_textract.json
# Processing 100514-000.pdf, page 1...
# ✓ Successfully processed 100514-000.pdf → 100514-000_page_1_textract.json
# Processing 102056-000.pdf, page 1...
# ✓ Successfully processed 102056-000.pdf → 102056-000_page_1_textract.json
# Processing 100533-000.pdf, page 1...
# ✓ Successfully processed 100533-000.pdf → 100533-000_page_1_textract.json
# Processing 10404-000.pdf, page 1...
# ✓ Successfully processed 10404-000.pdf → 10404-000_page_1_textract.json
# Processing 10407-000.pdf, page 1...
# ✓ Successfully processed 10407-000.pdf → 10407-000_page_1_textract.json
# Processing 100548-000.pdf, page 1...
# ✓ Successfully processed 100548-000.pdf → 100548-000_page_1_textract.json
# Processing 10375-005.pdf, page 1...
# ✓ Successfully processed 10375-005.pdf → 10375-005_page_1_textract.json
# Processing 100525-000.pdf, page 1...
# ✓ Successfully processed 100525-000.pdf → 100525-000_page_1_textract.json
# Processing 10408-000.pdf, page 1...
# ✓ Successfully processed 10408-000.pdf → 10408-000_page_1_textract.json
# Processing 10384-004.pdf, page 1...
# ✓ Successfully processed 10384-004.pdf → 10384-004_page_1_textract.json
# Processing 100527-000.pdf, page 1...
# ✓ Successfully processed 100527-000.pdf → 100527-000_page_1_textract.json
# Processing 10375-002.pdf, page 1...
# ✓ Successfully processed 10375-002.pdf → 10375-002_page_1_textract.json
# Processing 10423-000.pdf, page 1...
# ✓ Successfully processed 10423-000.pdf → 10423-000_page_1_textract.json
# Processing 100602-000.pdf, page 1...
# ✓ Successfully processed 100602-000.pdf → 100602-000_page_1_textract.json
# Processing 10426-000.pdf, page 1...
# ✓ Successfully processed 10426-000.pdf → 10426-000_page_1_textract.json
# Processing 100509-000.pdf, page 1...
# ✓ Successfully processed 100509-000.pdf → 100509-000_page_1_textract.json
# Processing 10428-000.pdf, page 1...
# ✓ Successfully processed 10428-000.pdf → 10428-000_page_1_textract.json
# Processing 100526-000.pdf, page 1...
# ✓ Successfully processed 100526-000.pdf → 100526-000_page_1_textract.json
# Processing 10259-004.pdf, page 1...
# ✓ Successfully processed 10259-004.pdf → 10259-004_page_1_textract.json
# Processing 100604-000.pdf, page 1...
# ✓ Successfully processed 100604-000.pdf → 100604-000_page_1_textract.json
# Processing 103905-001.pdf, page 1...
# ✓ Successfully processed 103905-001.pdf → 103905-001_page_1_textract.json
# Processing 100549-000.pdf, page 1...
# ✓ Successfully processed 100549-000.pdf → 100549-000_page_1_textract.json
# Processing 10442-000.pdf, page 1...
# ✓ Successfully processed 10442-000.pdf → 10442-000_page_1_textract.json
# Processing 103905-002.pdf, page 1...
# ✓ Successfully processed 103905-002.pdf → 103905-002_page_1_textract.json
# Processing 100606-000.pdf, page 1...
# ✓ Successfully processed 100606-000.pdf → 100606-000_page_1_textract.json
# Processing 100627-000.pdf, page 1...
# ✓ Successfully processed 100627-000.pdf → 100627-000_page_1_textract.json
# Processing 10375-007.pdf, page 1...
# ✓ Successfully processed 10375-007.pdf → 10375-007_page_1_textract.json
# Processing 100538-000.pdf, page 1...
# ✓ Successfully processed 100538-000.pdf → 100538-000_page_1_textract.json
# Processing 102437-000.pdf, page 1...
# ✓ Successfully processed 102437-000.pdf → 102437-000_page_1_textract.json
# Processing 10352-001.pdf, page 1...
# ✓ Successfully processed 10352-001.pdf → 10352-001_page_1_textract.json
# Processing 10380-001.pdf, page 1...
# ✓ Successfully processed 10380-001.pdf → 10380-001_page_1_textract.json
# Processing 100607-000.pdf, page 1...
# ✓ Successfully processed 100607-000.pdf → 100607-000_page_1_textract.json
# Processing 100605-000.pdf, page 1...
# ✓ Successfully processed 100605-000.pdf → 100605-000_page_1_textract.json
# Processing 100609-000.pdf, page 1...
# ✓ Successfully processed 100609-000.pdf → 100609-000_page_1_textract.json
# Processing 100615-000.pdf, page 1...
# ✓ Successfully processed 100615-000.pdf → 100615-000_page_1_textract.json
# Processing 100608-000.pdf, page 1...
# ✓ Successfully processed 100608-000.pdf → 100608-000_page_1_textract.json
# Processing 10377-001.pdf, page 1...
# ✓ Successfully processed 10377-001.pdf → 10377-001_page_1_textract.json
# Processing 102459-000.pdf, page 1...
# ✓ Successfully processed 102459-000.pdf → 102459-000_page_1_textract.json
# Processing 102706-000.pdf, page 1...
# ✓ Successfully processed 102706-000.pdf → 102706-000_page_1_textract.json
# Processing 100612-000.pdf, page 1...
# ✓ Successfully processed 100612-000.pdf → 100612-000_page_1_textract.json
# Processing 10384-005.pdf, page 1...
# ✓ Successfully processed 10384-005.pdf → 10384-005_page_1_textract.json
# Processing 102917-000.pdf, page 1...
# ✓ Successfully processed 102917-000.pdf → 102917-000_page_1_textract.json
# Processing 100613-000.pdf, page 1...
# ✓ Successfully processed 100613-000.pdf → 100613-000_page_1_textract.json
# Processing 10375-003.pdf, page 1...
# ✓ Successfully processed 10375-003.pdf → 10375-003_page_1_textract.json
# Processing 102502-000.pdf, page 1...
# ✓ Successfully processed 102502-000.pdf → 102502-000_page_1_textract.json
# Processing 102646-000.pdf, page 1...
# ✓ Successfully processed 102646-000.pdf → 102646-000_page_1_textract.json
# Processing 102451-000.pdf, page 1...
# ✓ Successfully processed 102451-000.pdf → 102451-000_page_1_textract.json
# Processing 100601-000.pdf, page 1...
# ✓ Successfully processed 100601-000.pdf → 100601-000_page_1_textract.json
# Processing 10206-000.pdf, page 1...
# ✓ Successfully processed 10206-000.pdf → 10206-000_page_1_textract.json
# Processing 100624-000.pdf, page 1...
# ✓ Successfully processed 100624-000.pdf → 100624-000_page_1_textract.json
# Processing 100619-000.pdf, page 1...
# ✓ Successfully processed 100619-000.pdf → 100619-000_page_1_textract.json
# Processing 100620-000.pdf, page 1...
# ✓ Successfully processed 100620-000.pdf → 100620-000_page_1_textract.json
# Processing 100617-000.pdf, page 1...
# ✓ Successfully processed 100617-000.pdf → 100617-000_page_1_textract.json
# Processing 104155-002.pdf, page 1...
# ✓ Successfully processed 104155-002.pdf → 104155-002_page_1_textract.json
# Processing 100610-000.pdf, page 1...
# ✓ Successfully processed 100610-000.pdf → 100610-000_page_1_textract.json
# Processing 104155-001.pdf, page 1...
# ✓ Successfully processed 104155-001.pdf → 104155-001_page_1_textract.json
# Processing 100625-000.pdf, page 1...
# ✓ Successfully processed 100625-000.pdf → 100625-000_page_1_textract.json
# Processing 100649-000.pdf, page 1...
# ✓ Successfully processed 100649-000.pdf → 100649-000_page_1_textract.json
# Processing 103190-000.pdf, page 1...
# ✓ Successfully processed 103190-000.pdf → 103190-000_page_1_textract.json
# Processing 10511-000.pdf, page 1...
# ✓ Successfully processed 10511-000.pdf → 10511-000_page_1_textract.json
# Processing 100629-000.pdf, page 1...
# ✓ Successfully processed 100629-000.pdf → 100629-000_page_1_textract.json
# Processing 101756-000.pdf, page 1...
# ✓ Successfully processed 101756-000.pdf → 101756-000_page_1_textract.json
# Processing 100621-000.pdf, page 1...
# ✓ Successfully processed 100621-000.pdf → 100621-000_page_1_textract.json
# Processing 10513-000.pdf, page 1...
# ✓ Successfully processed 10513-000.pdf → 10513-000_page_1_textract.json
# Processing 10225-000.pdf, page 1...
# ✓ Successfully processed 10225-000.pdf → 10225-000_page_1_textract.json
# Processing 1046-002.pdf, page 1...
# ✓ Successfully processed 1046-002.pdf → 1046-002_page_1_textract.json
# Processing 102269-000.pdf, page 1...
# ✓ Successfully processed 102269-000.pdf → 102269-000_page_1_textract.json
# Processing 100647-000.pdf, page 1...
# ✓ Successfully processed 100647-000.pdf → 100647-000_page_1_textract.json
# Processing 100630-000.pdf, page 1...
# ✓ Successfully processed 100630-000.pdf → 100630-000_page_1_textract.json
# Processing 100646-000.pdf, page 1...
# ✓ Successfully processed 100646-000.pdf → 100646-000_page_1_textract.json
# Processing 100641-000.pdf, page 1...
# ✓ Successfully processed 100641-000.pdf → 100641-000_page_1_textract.json
# Processing 10526-000.pdf, page 1...
# ✓ Successfully processed 10526-000.pdf → 10526-000_page_1_textract.json
# Processing 10375-006.pdf, page 1...
# ✓ Successfully processed 10375-006.pdf → 10375-006_page_1_textract.json
# Processing 10205-001.pdf, page 1...
# ✓ Successfully processed 10205-001.pdf → 10205-001_page_1_textract.json
# Processing 100623-000.pdf, page 1...
# ✓ Successfully processed 100623-000.pdf → 100623-000_page_1_textract.json
# Processing 10537-000.pdf, page 1...
# ✓ Successfully processed 10537-000.pdf → 10537-000_page_1_textract.json
# Processing 10530-000.pdf, page 1...
# ✓ Successfully processed 10530-000.pdf → 10530-000_page_1_textract.json
# Processing 102596-000.pdf, page 1...
# ✓ Successfully processed 102596-000.pdf → 102596-000_page_1_textract.json
# Processing 100644-000.pdf, page 1...
# ✓ Successfully processed 100644-000.pdf → 100644-000_page_1_textract.json
# Processing 10263-000.pdf, page 1...
# ✓ Successfully processed 10263-000.pdf → 10263-000_page_1_textract.json
# Processing 104067-000.pdf, page 1...
# ✓ Successfully processed 104067-000.pdf → 104067-000_page_1_textract.json
# Processing 100650-000.pdf, page 1...
# ✓ Successfully processed 100650-000.pdf → 100650-000_page_1_textract.json
# Processing 102703-000.pdf, page 1...
# ✓ Successfully processed 102703-000.pdf → 102703-000_page_1_textract.json
# Processing 10514-002.pdf, page 1...
# ✓ Successfully processed 10514-002.pdf → 10514-002_page_1_textract.json
# Processing 102704-000.pdf, page 1...
# ✓ Successfully processed 102704-000.pdf → 102704-000_page_1_textract.json
# Processing 100632-000.pdf, page 1...
# ✓ Successfully processed 100632-000.pdf → 100632-000_page_1_textract.json
# Processing 100628-000.pdf, page 1...
# ✓ Successfully processed 100628-000.pdf → 100628-000_page_1_textract.json
# Processing 103063-000.pdf, page 1...
# ✓ Successfully processed 103063-000.pdf → 103063-000_page_1_textract.json
# Processing 100652-000.pdf, page 1...
# ✓ Successfully processed 100652-000.pdf → 100652-000_page_1_textract.json
# Processing 10470-001.pdf, page 1...
# ✓ Successfully processed 10470-001.pdf → 10470-001_page_1_textract.json
# Processing 102705-000.pdf, page 1...
# ✓ Successfully processed 102705-000.pdf → 102705-000_page_1_textract.json
# Processing 101961-000.pdf, page 1...
# ✓ Successfully processed 101961-000.pdf → 101961-000_page_1_textract.json
# Processing 100643-000.pdf, page 1...
# ✓ Successfully processed 100643-000.pdf → 100643-000_page_1_textract.json
# Processing 100651-000.pdf, page 1...
# ✓ Successfully processed 100651-000.pdf → 100651-000_page_1_textract.json
# Processing 10579-000.pdf, page 1...
# ✓ Successfully processed 10579-000.pdf → 10579-000_page_1_textract.json
# Processing 101962-000.pdf, page 1...
# ✓ Successfully processed 101962-000.pdf → 101962-000_page_1_textract.json
# Processing 10289-000.pdf, page 1...
# ✓ Successfully processed 10289-000.pdf → 10289-000_page_1_textract.json
# Processing 105-004.pdf, page 1...
# ✓ Successfully processed 105-004.pdf → 105-004_page_1_textract.json
# Processing 100977-000.pdf, page 1...
# ✓ Successfully processed 100977-000.pdf → 100977-000_page_1_textract.json
# Processing 100601-001.pdf, page 1...
# ✓ Successfully processed 100601-001.pdf → 100601-001_page_1_textract.json
# Processing 103905-000.pdf, page 1...
# ✓ Successfully processed 103905-000.pdf → 103905-000_page_1_textract.json
# Processing 10511-005.pdf, page 1...
# ✓ Successfully processed 10511-005.pdf → 10511-005_page_1_textract.json
# Processing 10218-000.pdf, page 1...
# ✓ Successfully processed 10218-000.pdf → 10218-000_page_1_textract.json
# Processing 10301-000.pdf, page 1...
# ✓ Successfully processed 10301-000.pdf → 10301-000_page_1_textract.json
# Processing 10144-002.pdf, page 1...
# ✓ Successfully processed 10144-002.pdf → 10144-002_page_1_textract.json
# Processing 10589-000.pdf, page 1...
# ✓ Successfully processed 10589-000.pdf → 10589-000_page_1_textract.json
# Processing 10513-002.pdf, page 1...
# ✓ Successfully processed 10513-002.pdf → 10513-002_page_1_textract.json
# Processing 100117-000.pdf, page 1...
# ✓ Successfully processed 100117-000.pdf → 100117-000_page_1_textract.json
# Processing 100957-000.pdf, page 1...
# ✓ Successfully processed 100957-000.pdf → 100957-000_page_1_textract.json
# Processing 10389-000.pdf, page 1...
# ✓ Successfully processed 10389-000.pdf → 10389-000_page_1_textract.json
# Processing 10511-004.pdf, page 1...
# ✓ Successfully processed 10511-004.pdf → 10511-004_page_1_textract.json
# Processing 102708-000.pdf, page 1...
# ✓ Successfully processed 102708-000.pdf → 102708-000_page_1_textract.json
# Processing 10511-003.pdf, page 1...
# ✓ Successfully processed 10511-003.pdf → 10511-003_page_1_textract.json
# Processing 10067-000.pdf, page 1...
# ✓ Successfully processed 10067-000.pdf → 10067-000_page_1_textract.json
# Processing 10529-001.pdf, page 1...
# ✓ Successfully processed 10529-001.pdf → 10529-001_page_1_textract.json
# Processing 105692-001.pdf, page 1...
# ✓ Successfully processed 105692-001.pdf → 105692-001_page_1_textract.json
# Processing 10388-000.pdf, page 1...
# ✓ Successfully processed 10388-000.pdf → 10388-000_page_1_textract.json
# Processing 100686-000.pdf, page 1...
# ✓ Successfully processed 100686-000.pdf → 100686-000_page_1_textract.json
# Processing 1046-004.pdf, page 1...
# ✓ Successfully processed 1046-004.pdf → 1046-004_page_1_textract.json
# Processing 102738-000.pdf, page 1...
# ✓ Successfully processed 102738-000.pdf → 102738-000_page_1_textract.json
# Processing 100690-000.pdf, page 1...
# ✓ Successfully processed 100690-000.pdf → 100690-000_page_1_textract.json
# Processing 10525-004.pdf, page 1...
# ✓ Successfully processed 10525-004.pdf → 10525-004_page_1_textract.json
# Processing 103859-000.pdf, page 1...
# ✓ Successfully processed 103859-000.pdf → 103859-000_page_1_textract.json
# Processing 100704-000.pdf, page 1...
# ✓ Successfully processed 100704-000.pdf → 100704-000_page_1_textract.json
# Processing 100699-000.pdf, page 1...
# ✓ Successfully processed 100699-000.pdf → 100699-000_page_1_textract.json
# Processing 100684-000.pdf, page 1...
# ✓ Successfully processed 100684-000.pdf → 100684-000_page_1_textract.json
# Processing 10617-000.pdf, page 1...
# ✓ Successfully processed 10617-000.pdf → 10617-000_page_1_textract.json
# Processing 100697-000.pdf, page 1...
# ✓ Successfully processed 100697-000.pdf → 100697-000_page_1_textract.json
# Processing 10537-002.pdf, page 1...
# ✓ Successfully processed 10537-002.pdf → 10537-002_page_1_textract.json
# Processing 10537-003.pdf, page 1...
# ✓ Successfully processed 10537-003.pdf → 10537-003_page_1_textract.json
# Processing 100691-000.pdf, page 1...
# ✓ Successfully processed 100691-000.pdf → 100691-000_page_1_textract.json
# Processing 10618-002.pdf, page 1...
# ✓ Successfully processed 10618-002.pdf → 10618-002_page_1_textract.json
# Processing 100689-000.pdf, page 1...
# ✓ Successfully processed 100689-000.pdf → 100689-000_page_1_textract.json
# Processing 10579-002.pdf, page 1...
# ✓ Successfully processed 10579-002.pdf → 10579-002_page_1_textract.json
# Processing 10620-002.pdf, page 1...
# ...
# ✓ Successfully processed 109988-000.pdf → 109988-000_page_1_textract.json
# Processing 11210-002.pdf, page 1...
# ✓ Successfully processed 11210-002.pdf → 11210-002_page_1_textract.json
# Processing 11035-002.pdf, page 1...
# ✓ Successfully processed 11035-002.pdf → 11035-002_page_1_textract.json
# Processing 11212-002.pdf, page 1...
# ✓ Successfully processed 11212-002.pdf → 11212-002_page_1_textract.json
# Processing 11293-000.pdf, page 1...
# ✓ Successfully processed 11293-000.pdf → 11293-000_page_1_textract.json
# Processing 11203-002.pdf, page 1...
# ✓ Successfully processed 11203-002.pdf → 11203-002_page_1_textract.json
# Processing 10422-000.pdf, page 1...
# ✓ Successfully processed 10422-000.pdf → 10422-000_page_1_textract.json
# Processing 11403-001.pdf, page 1...
# ✓ Successfully processed 11403-001.pdf → 11403-001_page_1_textract.json
# Processing 11058-001.pdf, page 1...
# ✓ Successfully processed 11058-001.pdf → 11058-001_page_1_textract.json
# Processing 11286-001.pdf, page 1...
# ✓ Successfully processed 11286-001.pdf → 11286-001_page_1_textract.json
# Processing 112558-000.pdf, page 1...
# ✓ Successfully processed 112558-000.pdf → 112558-000_page_1_textract.json
# Processing 110791-000.pdf, page 1...
# ✓ Successfully processed 110791-000.pdf → 110791-000_page_1_textract.json
# Processing 112789-000.pdf, page 1...
# ✓ Successfully processed 112789-000.pdf → 112789-000_page_1_textract.json
# Processing 110531-000.pdf, page 1...
# ✓ Successfully processed 110531-000.pdf → 110531-000_page_1_textract.json
# Processing 110387-000.pdf, page 1...
# ✓ Successfully processed 110387-000.pdf → 110387-000_page_1_textract.json
# Processing 110390-000.pdf, page 1...
# ✓ Successfully processed 110390-000.pdf → 110390-000_page_1_textract.json
# Processing 11224-002.pdf, page 1...
# ✓ Successfully processed 11224-002.pdf → 11224-002_page_1_textract.json
# Processing 10851-001.pdf, page 1...
# ✓ Successfully processed 10851-001.pdf → 10851-001_page_1_textract.json
# Processing 11196-000.pdf, page 1...
# ✓ Successfully processed 11196-000.pdf → 11196-000_page_1_textract.json
# Processing 11300-000.pdf, page 1...
# ✓ Successfully processed 11300-000.pdf → 11300-000_page_1_textract.json
# Processing 111260-000.pdf, page 1...
# ✓ Successfully processed 111260-000.pdf → 111260-000_page_1_textract.json
# Processing 11232-002.pdf, page 1...
# ✓ Successfully processed 11232-002.pdf → 11232-002_page_1_textract.json
# Processing 110533-000.pdf, page 1...
# ✓ Successfully processed 110533-000.pdf → 110533-000_page_1_textract.json
# Processing 11414-001.pdf, page 1...
# ✓ Successfully processed 11414-001.pdf → 11414-001_page_1_textract.json
# Processing 11601-001.pdf, page 1...
# ✓ Successfully processed 11601-001.pdf → 11601-001_page_1_textract.json
# Processing 110534-000.pdf, page 1...
# ✓ Successfully processed 110534-000.pdf → 110534-000_page_1_textract.json
# Processing 110532-000.pdf, page 1...
# ✓ Successfully processed 110532-000.pdf → 110532-000_page_1_textract.json
# Processing 110537-000.pdf, page 1...
# ✓ Successfully processed 110537-000.pdf → 110537-000_page_1_textract.json
# Processing 110535-000.pdf, page 1...
# ✓ Successfully processed 110535-000.pdf → 110535-000_page_1_textract.json
# Processing 110540-000.pdf, page 1...
# ✓ Successfully processed 110540-000.pdf → 110540-000_page_1_textract.json
# Processing 11855-000.pdf, page 1...
# ✓ Successfully processed 11855-000.pdf → 11855-000_page_1_textract.json
# Processing 110876-000.pdf, page 1...
# ✓ Successfully processed 110876-000.pdf → 110876-000_page_1_textract.json
# Processing 11865-000.pdf, page 1...
# ✓ Successfully processed 11865-000.pdf → 11865-000_page_1_textract.json
# Processing 11873-000.pdf, page 1...
# ✓ Successfully processed 11873-000.pdf → 11873-000_page_1_textract.json
# Processing 11220-000.pdf, page 1...
# ✓ Successfully processed 11220-000.pdf → 11220-000_page_1_textract.json
# Processing 110828-000.pdf, page 1...
# ✓ Successfully processed 110828-000.pdf → 110828-000_page_1_textract.json
# Processing 110539-000.pdf, page 1...
# ✓ Successfully processed 110539-000.pdf → 110539-000_page_1_textract.json
# Processing 110536-000.pdf, page 1...
# ✓ Successfully processed 110536-000.pdf → 110536-000_page_1_textract.json
# Processing 11543-001.pdf, page 1...
# ✓ Successfully processed 11543-001.pdf → 11543-001_page_1_textract.json
# Processing 11228-002.pdf, page 1...
# ✓ Successfully processed 11228-002.pdf → 11228-002_page_1_textract.json
# Processing 11236-002.pdf, page 1...
# ✓ Successfully processed 11236-002.pdf → 11236-002_page_1_textract.json
# Processing 1159-001.pdf, page 1...
# ✓ Successfully processed 1159-001.pdf → 1159-001_page_1_textract.json
# Processing 110827-000.pdf, page 1...
# ✓ Successfully processed 110827-000.pdf → 110827-000_page_1_textract.json
# Processing 110790-000.pdf, page 1...
# ✓ Successfully processed 110790-000.pdf → 110790-000_page_1_textract.json
# Processing 110726-000.pdf, page 1...
# ✓ Successfully processed 110726-000.pdf → 110726-000_page_1_textract.json
# Processing 1190-000.pdf, page 1...
# ✓ Successfully processed 1190-000.pdf → 1190-000_page_1_textract.json
# Processing 11207-002.pdf, page 1...
# ✓ Successfully processed 11207-002.pdf → 11207-002_page_1_textract.json
# Processing 112836-000.pdf, page 1...
# ✓ Successfully processed 112836-000.pdf → 112836-000_page_1_textract.json
# Processing 110389-000.pdf, page 1...
# ✓ Successfully processed 110389-000.pdf → 110389-000_page_1_textract.json
# Processing 11065-002.pdf, page 1...
# ✓ Successfully processed 11065-002.pdf → 11065-002_page_1_textract.json
# Processing 11961-000.pdf, page 1...
# ✓ Successfully processed 11961-000.pdf → 11961-000_page_1_textract.json
# Processing 11259-002.pdf, page 1...
# ✓ Successfully processed 11259-002.pdf → 11259-002_page_1_textract.json
# Processing 11035-001.pdf, page 1...
# ✓ Successfully processed 11035-001.pdf → 11035-001_page_1_textract.json
# Processing 114219-000.pdf, page 1...
# ✓ Successfully processed 114219-000.pdf → 114219-000_page_1_textract.json
# Processing 118-003.pdf, page 1...
# ✓ Successfully processed 118-003.pdf → 118-003_page_1_textract.json
# Processing 11674-002.pdf, page 1...
# ✓ Successfully processed 11674-002.pdf → 11674-002_page_1_textract.json
# Processing 113343-000.pdf, page 1...
# ✓ Successfully processed 113343-000.pdf → 113343-000_page_1_textract.json
# Processing 11970-000.pdf, page 1...
# ✓ Successfully processed 11970-000.pdf → 11970-000_page_1_textract.json
# Processing 11950-003.pdf, page 1...
# ✓ Successfully processed 11950-003.pdf → 11950-003_page_1_textract.json
# Processing 11995-000.pdf, page 1...
# ✓ Successfully processed 11995-000.pdf → 11995-000_page_1_textract.json
# Processing 11057-001.pdf, page 1...
# ✓ Successfully processed 11057-001.pdf → 11057-001_page_1_textract.json
# Processing 111395-000.pdf, page 1...
# ✓ Successfully processed 111395-000.pdf → 111395-000_page_1_textract.json
# Processing 111136-000.pdf, page 1...
# ✓ Successfully processed 111136-000.pdf → 111136-000_page_1_textract.json
# Processing 11999-000.pdf, page 1...
# ✓ Successfully processed 11999-000.pdf → 11999-000_page_1_textract.json
# Processing 12009-000.pdf, page 1...
# ✓ Successfully processed 12009-000.pdf → 12009-000_page_1_textract.json
# Processing 11159-003.pdf, page 1...
# ✓ Successfully processed 11159-003.pdf → 11159-003_page_1_textract.json
# Processing 11885-004.pdf, page 1...
# ✓ Successfully processed 11885-004.pdf → 11885-004_page_1_textract.json
# Processing 11061-001.pdf, page 1...
# ✓ Successfully processed 11061-001.pdf → 11061-001_page_1_textract.json
# Processing 110538-000.pdf, page 1...
# ✓ Successfully processed 110538-000.pdf → 110538-000_page_1_textract.json
# Processing 118-000.pdf, page 1...
# ✓ Successfully processed 118-000.pdf → 118-000_page_1_textract.json
# Processing 12014-000.pdf, page 1...
# ✓ Successfully processed 12014-000.pdf → 12014-000_page_1_textract.json
# Processing 11405-001.pdf, page 1...
# ✓ Successfully processed 11405-001.pdf → 11405-001_page_1_textract.json
# Processing 12018-000.pdf, page 1...
# ✓ Successfully processed 12018-000.pdf → 12018-000_page_1_textract.json
# Processing 12026-000.pdf, page 1...
# ✓ Successfully processed 12026-000.pdf → 12026-000_page_1_textract.json
# Processing 100746-000.pdf, page 1...
# ✓ Successfully processed 100746-000.pdf → 100746-000_page_1_textract.json
# Processing 11950-006.pdf, page 1...
# ✓ Successfully processed 11950-006.pdf → 11950-006_page_1_textract.json
# Processing 110388-000.pdf, page 1...
# ✓ Successfully processed 110388-000.pdf → 110388-000_page_1_textract.json
# Processing 11950-005.pdf, page 1...
# ✓ Successfully processed 11950-005.pdf → 11950-005_page_1_textract.json
# Processing 113730-000.pdf, page 1...
# ✓ Successfully processed 113730-000.pdf → 113730-000_page_1_textract.json
# Processing 11950-008.pdf, page 1...
# ✓ Successfully processed 11950-008.pdf → 11950-008_page_1_textract.json
# Processing 12029-000.pdf, page 1...
# ✓ Successfully processed 12029-000.pdf → 12029-000_page_1_textract.json
# Processing 11950-007.pdf, page 1...
# ✓ Successfully processed 11950-007.pdf → 11950-007_page_1_textract.json
# Processing 12035-001.pdf, page 1...
# ✓ Successfully processed 12035-001.pdf → 12035-001_page_1_textract.json
# Processing 12032-000.pdf, page 1...
# ✓ Successfully processed 12032-000.pdf → 12032-000_page_1_textract.json
# Processing 11799-001.pdf, page 1...
# ✓ Successfully processed 11799-001.pdf → 11799-001_page_1_textract.json
# Processing 11894-001.pdf, page 1...
# ✓ Successfully processed 11894-001.pdf → 11894-001_page_1_textract.json
# Processing 11961-003.pdf, page 1...
# ✓ Successfully processed 11961-003.pdf → 11961-003_page_1_textract.json
# Processing 12135-000.pdf, page 1...
# ✓ Successfully processed 12135-000.pdf → 12135-000_page_1_textract.json
# Processing 12136-000.pdf, page 1...
# ✓ Successfully processed 12136-000.pdf → 12136-000_page_1_textract.json
# Processing 11372-001.pdf, page 1...
# ✓ Successfully processed 11372-001.pdf → 11372-001_page_1_textract.json
# Processing 12142-000.pdf, page 1...
# ✓ Successfully processed 12142-000.pdf → 12142-000_page_1_textract.json
# Processing 12150-000.pdf, page 1...
# ✓ Successfully processed 12150-000.pdf → 12150-000_page_1_textract.json
# Processing 111791-000.pdf, page 1...
# ✓ Successfully processed 111791-000.pdf → 111791-000_page_1_textract.json
# Processing 12151-000.pdf, page 1...
# ✓ Successfully processed 12151-000.pdf → 12151-000_page_1_textract.json
# Processing 12146-000.pdf, page 1...
# ✓ Successfully processed 12146-000.pdf → 12146-000_page_1_textract.json
# Processing 10774-001.pdf, page 1...
# ✓ Successfully processed 10774-001.pdf → 10774-001_page_1_textract.json
# Processing 113859-000.pdf, page 1...
# ✓ Successfully processed 113859-000.pdf → 113859-000_page_1_textract.json
# Processing 11292-000.pdf, page 1...
# ✓ Successfully processed 11292-000.pdf → 11292-000_page_1_textract.json
# Processing 111534-000.pdf, page 1...
# ✓ Successfully processed 111534-000.pdf → 111534-000_page_1_textract.json
# Processing 112699-000.pdf, page 1...
# ✓ Successfully processed 112699-000.pdf → 112699-000_page_1_textract.json
# Processing 11239-000.pdf, page 1...
# ✓ Successfully processed 11239-000.pdf → 11239-000_page_1_textract.json
# Processing 104274-000.pdf, page 1...
# ✓ Successfully processed 104274-000.pdf → 104274-000_page_1_textract.json
# Processing 11171-001.pdf, page 1...
# ✓ Successfully processed 11171-001.pdf → 11171-001_page_1_textract.json
# Processing 11411-001.pdf, page 1...
# ✓ Successfully processed 11411-001.pdf → 11411-001_page_1_textract.json
# Processing 12154-000.pdf, page 1...
# ✓ Successfully processed 12154-000.pdf → 12154-000_page_1_textract.json
# Processing 11295-000.pdf, page 1...
# ✓ Successfully processed 11295-000.pdf → 11295-000_page_1_textract.json
# Processing 113591-000.pdf, page 1...
# ✓ Successfully processed 113591-000.pdf → 113591-000_page_1_textract.json
# Processing 10838-000.pdf, page 1...
# ✓ Successfully processed 10838-000.pdf → 10838-000_page_1_textract.json
# Processing 11063-001.pdf, page 1...
# ✓ Successfully processed 11063-001.pdf → 11063-001_page_1_textract.json
# Processing 106491-000.pdf, page 1...
# ✓ Successfully processed 106491-000.pdf → 106491-000_page_1_textract.json
# Processing 112728-000.pdf, page 1...
# ✓ Successfully processed 112728-000.pdf → 112728-000_page_1_textract.json
# Processing 12182-000.pdf, page 1...
# ✓ Successfully processed 12182-000.pdf → 12182-000_page_1_textract.json
# Processing 12184-001.pdf, page 1...
# ✓ Successfully processed 12184-001.pdf → 12184-001_page_1_textract.json
# Processing 111258-000.pdf, page 1...
# ✓ Successfully processed 111258-000.pdf → 111258-000_page_1_textract.json
# Processing 12191-005.pdf, page 1...
# ✓ Successfully processed 12191-005.pdf → 12191-005_page_1_textract.json
# Processing 111364-000.pdf, page 1...
# ✓ Successfully processed 111364-000.pdf → 111364-000_page_1_textract.json
# Processing 12169-002.pdf, page 1...
# ✓ Successfully processed 12169-002.pdf → 12169-002_page_1_textract.json
# Processing 11266-000.pdf, page 1...
# ✓ Successfully processed 11266-000.pdf → 11266-000_page_1_textract.json
# Processing 12199-001.pdf, page 1...
# ✓ Successfully processed 12199-001.pdf → 12199-001_page_1_textract.json
# Processing 12200-000.pdf, page 1...
# ✓ Successfully processed 12200-000.pdf → 12200-000_page_1_textract.json
# Processing 12204-000.pdf, page 1...
# ✓ Successfully processed 12204-000.pdf → 12204-000_page_1_textract.json
# Processing 12208-001.pdf, page 1...
# ✓ Successfully processed 12208-001.pdf → 12208-001_page_1_textract.json
# Processing 11364-000.pdf, page 1...
# ✓ Successfully processed 11364-000.pdf → 11364-000_page_1_textract.json
# Processing 11301-000.pdf, page 1...
# ✓ Successfully processed 11301-000.pdf → 11301-000_page_1_textract.json
# Processing 110179-000.pdf, page 1...
# ✓ Successfully processed 110179-000.pdf → 110179-000_page_1_textract.json
# Processing 113940-000.pdf, page 1...
# ✓ Successfully processed 113940-000.pdf → 113940-000_page_1_textract.json
# Processing 11897-001.pdf, page 1...
# ✓ Successfully processed 11897-001.pdf → 11897-001_page_1_textract.json
# Processing 11511-001.pdf, page 1...
# ✓ Successfully processed 11511-001.pdf → 11511-001_page_1_textract.json
# Processing 114453-000.pdf, page 1...
# ✓ Successfully processed 114453-000.pdf → 114453-000_page_1_textract.json
# Processing 12167-001.pdf, page 1...
# ✓ Successfully processed 12167-001.pdf → 12167-001_page_1_textract.json
# Processing 11363-000.pdf, page 1...
# ✓ Successfully processed 11363-000.pdf → 11363-000_page_1_textract.json
# Processing 11326-000.pdf, page 1...
# ✓ Successfully processed 11326-000.pdf → 11326-000_page_1_textract.json
# Processing 11905-001.pdf, page 1...
# ✓ Successfully processed 11905-001.pdf → 11905-001_page_1_textract.json
# Processing 12152-001.pdf, page 1...
# ✓ Successfully processed 12152-001.pdf → 12152-001_page_1_textract.json
# Processing 11275-001.pdf, page 1...
# ✓ Successfully processed 11275-001.pdf → 11275-001_page_1_textract.json
# Processing 11379-002.pdf, page 1...
# ✓ Successfully processed 11379-002.pdf → 11379-002_page_1_textract.json
# Processing 11385-000.pdf, page 1...
# ✓ Successfully processed 11385-000.pdf → 11385-000_page_1_textract.json
# Processing 11254-002.pdf, page 1...
# ✓ Successfully processed 11254-002.pdf → 11254-002_page_1_textract.json
# Processing 11365-000.pdf, page 1...
# ✓ Successfully processed 11365-000.pdf → 11365-000_page_1_textract.json
# Processing 11334-000.pdf, page 1...
# ✓ Successfully processed 11334-000.pdf → 11334-000_page_1_textract.json
# Processing 1159-000.pdf, page 1...
# ✓ Successfully processed 1159-000.pdf → 1159-000_page_1_textract.json
# Processing 12176-001.pdf, page 1...
# ✓ Successfully processed 12176-001.pdf → 12176-001_page_1_textract.json
# Processing 11961-004.pdf, page 1...
# ✓ Successfully processed 11961-004.pdf → 11961-004_page_1_textract.json
# Processing 11383-002.pdf, page 1...
# ✓ Successfully processed 11383-002.pdf → 11383-002_page_1_textract.json
# Processing 12156-003.pdf, page 1...
# ✓ Successfully processed 12156-003.pdf → 12156-003_page_1_textract.json
# Processing 11799-003.pdf, page 1...
# ✓ Successfully processed 11799-003.pdf → 11799-003_page_1_textract.json
# Processing 11359-000.pdf, page 1...
# ✓ Successfully processed 11359-000.pdf → 11359-000_page_1_textract.json
# Processing 113064-000.pdf, page 1...

# %% [markdown]
# ## Save Results

# %%
# Save summary and error files
if results or skipped:
    # Count existing files if CLOBBER was False
    existing_files = []
    if not CLOBBER:
        for json_file in output_dir.glob("*.json"):
            if json_file.name != "processing_summary.json":
                existing_files.append(json_file.name)
    
    # Save summary of all results (including existing ones)
    summary = {
        'clobber_mode': CLOBBER,
        'newly_processed_count': len(results),
        'skipped_count': len(skipped),
        'error_count': len(errors),
        'total_existing_files': len(existing_files) if not CLOBBER else 0,
        'newly_processed_files': [{
            'filename': r['filename'],
            'page_number': r['page_number'],
            'json_file': r['json_file']
        } for r in results],
        'skipped_files': skipped
    }
    
    with open(output_dir / 'processing_summary.json', 'w') as f:
        json.dump(summary, f, indent=2)

# Save errors if any
if errors:
    errors_df = pd.DataFrame(errors)
    errors_df.to_csv(output_dir / 'processing_errors.csv', index=False)
    print(f"Errors saved to: {output_dir / 'processing_errors.csv'}")

print(f"Results saved to: {output_dir}")
print(f"Newly processed JSON files: {len(results)}")
if not CLOBBER and skipped:
    print(f"Skipped existing files: {len(skipped)}")
print(f"Summary file: processing_summary.json")

# %% [markdown]
# ## Display Sample Results

# %%
# Display summary statistics
total_processed = len(results) + len(skipped)
if total_processed > 0:
    print("Processing Summary:")
    print(f"- Total documents in scope: {total_processed}")
    print(f"- Newly processed: {len(results)}")
    if not CLOBBER and skipped:
        print(f"- Skipped (already processed): {len(skipped)}")
    print(f"- Total errors: {len(errors)}")
    if len(results) + len(errors) > 0:
        print(f"- Success rate: {len(results)/(len(results)+len(errors))*100:.1f}%")
    
    # Show sample of extracted text from first result
    if len(results) > 0:
        sample_result = results[0]
        print(f"\nSample extraction from {sample_result['filename']} (page {sample_result['page_number']}):")
        
        # Load the JSON file to get Textract response
        json_path = output_dir / sample_result['json_file']
        with open(json_path, 'r') as f:
            textract_response = json.load(f)
        
        # Extract text blocks from Textract response
        textract_blocks = textract_response.get('Blocks', [])
        text_blocks = [block['Text'] for block in textract_blocks if block['BlockType'] == 'LINE']
        
        print("First 10 lines of detected text:")
        for i, text in enumerate(text_blocks[:10]):
            print(f"{i+1:2d}: {text}")
            
        # Show key-value pairs if detected
        key_value_blocks = [block for block in textract_blocks if block['BlockType'] == 'KEY_VALUE_SET']
        if key_value_blocks:
            print(f"\nDetected {len(key_value_blocks)} key-value pairs in the form.")
else:
    print("No files were processed.")

# %% [markdown]
# ## Error Analysis

# %%
if errors:
    print("Error Analysis:")
    errors_df = pd.DataFrame(errors)
    print(errors_df.head(10))
    
    # Count error types
    error_types = errors_df['error'].value_counts()
    print("\nError type distribution:")
    print(error_types)
else:
    print("No errors to analyze!")
